# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorJones/dio_desafio_etl/blob/main/Desafio_Explorando_IA_Generativa_em_um_Pipeline_de_ETL_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sdw2023_api_url = 'https://sdw-2023-prd.up.railway.app'

import pandas as pd

df = pd.read_csv("SDW2023.csv")
user_ids = df["UserID"].tolist()
print(user_ids)

import requests
import json

def get_user(id):
  ids = requests.get(f"{sdw2023_api_url}/users/{id}")
  return ids.json() if ids.status_code == 200 else None

users = [user for id in user_ids if (user := get_user(id)) is not None]
print(json.dumps(users, indent=2))

def resposta_automatica(user):
  resposta = f"{user['name']}, Não existe forma melhor de multiplicar o seu dinheiro do que investindo."
  return resposta

for user in users:
  news = resposta_automatica(user)
  print(news)
  user['news'].append({
      "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
      "description": news
  })

def update_user(user):
  response = requests.put(f"{sdw2023_api_url}/users/{user['id']}", json=user)
  return True if response.status_code == 200 else False

for user in users:
  success = update_user(user)
  print(f"User {user['name']} updated? {success}!")
# Out:
# [1573, 1574, 1575]
# [
#   {
#     "id": 1573,
#     "name": "Vitor Jones",
#     "account": {
#       "id": 1654,
#       "number": "10412-4",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 1519,
#       "number": "**** **** **** 7547",
#       "limit": 1000.0
#     },
#     "features": [
#       {
#         "id": 508,
#         "icon": "string",
#         "description": "string"
#       }
#     ],
#     "news": [
#       {
#         "id": 3265,
#         "icon": "string",
#         "description": "string"
#       },
#       {
#         "id": 3279,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#         "description": null
#       },
#       {
#         "id": 3280,
#         "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
# ...
